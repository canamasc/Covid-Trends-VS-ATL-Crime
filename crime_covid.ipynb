# %%
import pandas as pd

# %%
# merge two cscv file
csv_path = pd.concat(map(pd.read_csv, ["crime_data1.csv", "covid_data.csv"]), ignore_index=True)
print(crime_covid_df)
# Out:
#         offense_id   rpt_date  occur_date occur_time           UC2_Literal  \
# 0       21320347.0   2/1/2021   1/31/2021      00:00  LARCENY-FROM VEHICLE
# 1      203661993.0   1/1/2021   1/31/2020      20:30  LARCENY-FROM VEHICLE
# 2      203662299.0   1/5/2021  12/31/2020      23:36  LARCENY-FROM VEHICLE
# 3      210010977.0  1/25/2021    1/1/2021      03:00            AUTO THEFT
# 4      210011211.0   1/1/2021    1/1/2021      05:43  LARCENY-FROM VEHICLE
# ...            ...        ...         ...        ...                   ...
# 16274          NaN        NaN         NaN        NaN                   NaN
# 16275          NaN        NaN         NaN        NaN                   NaN
# 16276          NaN        NaN         NaN        NaN                   NaN
# 16277          NaN        NaN         NaN        NaN                   NaN
# 16278          NaN        NaN         NaN        NaN                   NaN
#
# ...

# %%
# DataFrame
crime_covid_df = pd.DataFrame(csv_path)
crime_covid_df.head(-1)
# Out:
#         offense_id   rpt_date  occur_date occur_time           UC2_Literal  \
# 0       21320347.0   2/1/2021   1/31/2021      00:00  LARCENY-FROM VEHICLE
# 1      203661993.0   1/1/2021   1/31/2020      20:30  LARCENY-FROM VEHICLE
# 2      203662299.0   1/5/2021  12/31/2020      23:36  LARCENY-FROM VEHICLE
# 3      210010977.0  1/25/2021    1/1/2021      03:00            AUTO THEFT
# 4      210011211.0   1/1/2021    1/1/2021      05:43  LARCENY-FROM VEHICLE
# ...            ...        ...         ...        ...                   ...
# 16273          NaN        NaN         NaN        NaN                   NaN
# 16274          NaN        NaN         NaN        NaN                   NaN
# 16275          NaN        NaN         NaN        NaN                   NaN
# 16276          NaN        NaN         NaN        NaN                   NaN
# 16277          NaN        NaN         NaN        NaN                   NaN
#
# ...
