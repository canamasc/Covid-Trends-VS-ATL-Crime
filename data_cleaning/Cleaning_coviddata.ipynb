# %%
import pandas as pd

# %%
covid_df = pd.read_csv('epicurve_rpt_date.csv')

use_df = covid_df[covid_df["county"]!="Georgia"]

use_df
# Out:
#             measure   county report_date  cases  deaths  cases_cum  death_cum  \
# 539    county_stats  Appling  2020-02-01      0       0          0          0
# 540    county_stats  Appling  2020-02-02      0       0          0          0
# 541    county_stats  Appling  2020-02-03      0       0          0          0
# 542    county_stats  Appling  2020-02-04      0       0          0          0
# 543    county_stats  Appling  2020-02-05      0       0          0          0
# ...             ...      ...         ...    ...     ...        ...        ...
# 87313  county_stats    Worth  2021-07-19      0       0       1207         62
# 87314  county_stats    Worth  2021-07-20      1       0       1208         62
# 87315  county_stats    Worth  2021-07-21      1       0       1209         62
# 87316  county_stats    Worth  2021-07-22      3       0       1212         62
# 87317  county_stats    Worth  2021-07-23      0       0       1212         62
#
# ...

# %%
use_df['use_date'] = pd.to_datetime(use_df['report_date'])

use1_df = use_df[((use_df["use_date"].dt.year==2020)&((use_df["use_date"].dt.month==9)|(use_df["use_date"].dt.month==10)|(use_df["use_date"].dt.month==11)|(use_df["use_date"].dt.month==12)))|((use_df["use_date"].dt.year==2021)&((use_df["use_date"].dt.month==1)|(use_df["use_date"].dt.month==2)|(use_df["use_date"].dt.month==3)))]
use1_df
# Out:
# /Users/ashtonsmith/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#             measure   county report_date  cases  deaths  cases_cum  death_cum  \
# 752    county_stats  Appling  2020-09-01      6       0        899         24
# 753    county_stats  Appling  2020-09-02      3       0        902         24
# 754    county_stats  Appling  2020-09-03      8       0        910         24
# 755    county_stats  Appling  2020-09-04     15       0        925         24
# 756    county_stats  Appling  2020-09-05      7       0        932         24
# ...

# %%
use1_df = use1_df[["county","use_date","total_cases","deaths"]]

use1_df
# Out:
#         county   use_date  total_cases  deaths
# 752    Appling 2020-09-01            7       0
# 753    Appling 2020-09-02            7       0
# 754    Appling 2020-09-03            8       0
# 755    Appling 2020-09-04           16       0
# 756    Appling 2020-09-05            8       0
# ...        ...        ...          ...     ...
# 87199    Worth 2021-03-27            1       0
# 87200    Worth 2021-03-28            1       0
# 87201    Worth 2021-03-29            3       0
# 87202    Worth 2021-03-30            0       0
# 87203    Worth 2021-03-31            1       1
#
# [34132 rows x 4 columns]

# %%
use1_df = use1_df[(use1_df["county"]=="Fulton")|(use1_df["county"]=="Dekalb")|(use1_df["county"]=="Clayton")]

use1_df
# Out:
#         county   use_date  total_cases  deaths
# 16922  Clayton 2020-09-01           53       3
# 16923  Clayton 2020-09-02           18       1
# 16924  Clayton 2020-09-03           39       3
# 16925  Clayton 2020-09-04           19       0
# 16926  Clayton 2020-09-05           22       2
# ...        ...        ...          ...     ...
# 32760   Fulton 2021-03-27          175       5
# 32761   Fulton 2021-03-28          107       0
# 32762   Fulton 2021-03-29          123       2
# 32763   Fulton 2021-03-30          134       3
# 32764   Fulton 2021-03-31          186       5
#
# [424 rows x 4 columns]

# %%
final_df = use1_df.dropna(how='any')

# %%
final_df.to_csv("covid_data.csv", index=False, header=True)
