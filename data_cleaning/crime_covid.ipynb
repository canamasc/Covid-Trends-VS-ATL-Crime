# %%
import pandas as pd

# %%
data1 = pd.read_csv('crime_data1.csv')
data2 = pd.read_csv('covid_data.csv')

output_df = pd.merge(data1, data2, how='left')

print(output)
# Out:
#        offense_id    rpt_date  occur_date occur_time           UC2_Literal  \
# 0        21320347    2/1/2021   1/31/2021      00:00  LARCENY-FROM VEHICLE
# 1       203661993    1/1/2021   1/31/2020      20:30  LARCENY-FROM VEHICLE
# 2       203662299    1/5/2021  12/31/2020      23:36  LARCENY-FROM VEHICLE
# 3       210010977   1/25/2021    1/1/2021      03:00            AUTO THEFT
# 4       210011211    1/1/2021    1/1/2021      05:43  LARCENY-FROM VEHICLE
# ...           ...         ...         ...        ...                   ...
# 15850   202920087  10/18/2020  10/18/2020       0:10               ROBBERY
# 15851   202810281   10/7/2020   10/7/2020       1:30               ROBBERY
# 15852   202770463   10/3/2020   10/3/2020       2:10            AUTO THEFT
# 15853   202671810   9/23/2020   9/23/2020      22:00           AGG ASSAULT
# 15854   203161000  11/11/2020   11/4/2020       0:00   LARCENY-NON VEHICLE
#
# ...

# %%
clean_df = output_df.dropna(how='any', inplace=False)
clean_df.drop(['rpt_date', 'occur_time'], inplace=True, axis=1)
crime_covid_df = pd.DataFrame(clean_df)
crime_covid_df.head(-1)
# Out:
# /Users/shangjungtsang/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#        offense_id  occur_date           UC2_Literal         neighborhood npu  \
# 0        21320347   1/31/2021  LARCENY-FROM VEHICLE             Downtown   M
# 1       203661993   1/31/2020  LARCENY-FROM VEHICLE             Downtown   M
# 2       203662299  12/31/2020  LARCENY-FROM VEHICLE             Downtown   M
# 3       210010977    1/1/2021            AUTO THEFT             Downtown   M
# 4       210011211    1/1/2021  LARCENY-FROM VEHICLE             Downtown   M
# ...           ...         ...                   ...                  ...  ..
# 15849   203330711  11/28/2020   LARCENY-NON VEHICLE  South River Gardens   Z
# ...

# %%
clean_df.to_csv("crime_covid2.csv", index=False, header=True)
